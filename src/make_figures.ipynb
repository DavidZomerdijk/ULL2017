# %%
import pickle
import numpy as np
import os
import sys
from dataset import Dataset
from lsc_subj_obj_transitive_verbs import SubjectObjectTransitiveVerbClasses
from lsc_subj_intransitive_verbs import SubjectIntransitiveVerbClasses
from lsc_verb_noun_pairs import LSCVerbClasses

# %%
data_model = pickle.load( open( "../out/all_pairs_lcs-100-50.pkl", "rb" ))
dataset  =  pickle.load( open( "../data/all_pairs-t10000.pkl", "rb" ))

# %%
p_vc_sorted = np.argsort(data_model.p_vc, axis=0)[-20:,:]
p_nc_sorted = np.argsort(data_model.p_nc, axis=0)[-20:,:]

# %%
top_n_idx = np.shape(p_vc_sorted)[1]
for cls in range(data_model.n_cs):
    print ("Class number %i"%(cls + 1))
    for idx in range(19,-1,-1):
        noun_idx = p_nc_sorted[idx,cls]
        verb_idx = p_vc_sorted[idx,cls]
        
        print (noun_idx)
        print (verb_idx)
        
        print ("Number %i of the verbe/nouns:"%(idx + 1))
        print ("     Verb:             %s   prob = %f"%(dataset.vs[verb_idx], data_model.p_vc[verb_idx,cls]))
        print ("     Noun:             %s   prob = %f"%(dataset.ns[noun_idx], data_model.p_nc[noun_idx,cls]))
    break
# Out:
# Class number 1
# 171
# 31
# Number 20 of the verbe/nouns:
#      Verb:             keep   prob = 0.423384
#      Noun:             life   prob = 0.021366
# 216
# 89
# Number 19 of the verbe/nouns:
#      Verb:             recov   prob = 0.040785
#      Noun:             effect   prob = 0.012926
# 1115
# 193
# Number 18 of the verbe/nouns:
#      Verb:             promis   prob = 0.011711
#      Noun:             power   prob = 0.010779
# 815
# 937
# Number 17 of the verbe/nouns:
#      Verb:             becom   prob = 0.008070
#      Noun:             history   prob = 0.010488
# 854
# 1331
# Number 16 of the verbe/nouns:
#      Verb:             entertain   prob = 0.006618
#      Noun:             reputation   prob = 0.009400
# 175
# 463
# Number 15 of the verbe/nouns:
#      Verb:             buttress   prob = 0.006463
#      Noun:             right   prob = 0.008463
# 1127
# 1061
# Number 14 of the verbe/nouns:
#      Verb:             measur   prob = 0.006462
#      Noun:             ability   prob = 0.008093
# 321
# 1534
# Number 13 of the verbe/nouns:
#      Verb:             laps   prob = 0.006449
#      Noun:             lives   prob = 0.007895
# 4717
# 1608
# Number 12 of the verbe/nouns:
#      Verb:             enrich   prob = 0.006377
#      Noun:             potential   prob = 0.007815
# 100
# 111
# Number 11 of the verbe/nouns:
#      Verb:             text   prob = 0.006369
#      Noun:             experience   prob = 0.007582
# 769
# 266
# Number 10 of the verbe/nouns:
#      Verb:             attract   prob = 0.006175
#      Noun:             advantage   prob = 0.007011
# 76
# 291
# Number 9 of the verbe/nouns:
#      Verb:             improv   prob = 0.005994
#      Noun:             implications   prob = 0.006738
# 208
# 655
# Number 8 of the verbe/nouns:
#      Verb:             swore   prob = 0.005846
#      Noun:             value   prob = 0.006731
# 532
# 120
# Number 7 of the verbe/nouns:
#      Verb:             last   prob = 0.005777
#      Noun:             responsibility   prob = 0.006620
# 1054
# 640
# Number 6 of the verbe/nouns:
#      Verb:             haunt   prob = 0.005676
#      Noun:             advantages   prob = 0.006185
# 220
# 593
# Number 5 of the verbe/nouns:
#      Verb:             carv   prob = 0.005461
#      Noun:             interest   prob = 0.006086
# 2725
# 995
# Number 4 of the verbe/nouns:
#      Verb:             resist   prob = 0.005294
#      Noun:             features   prob = 0.005938
# 116
# 2587
# Number 3 of the verbe/nouns:
#      Verb:             liken   prob = 0.004993
#      Noun:             one   prob = 0.005367
# 1053
# 581
# Number 2 of the verbe/nouns:
#      Verb:             descend   prob = 0.004691
#      Noun:             nothing   prob = 0.005181
# 608
# 2043
# Number 1 of the verbe/nouns:
#      Verb:             jeer   prob = 0.004364
#      Noun:             confidence   prob = 0.005046

# %%
def make_table_rows(dataset, p_vc_sorted, p_nc_sorted, cls):
    rows = []
    for v_idx in range(19, -1, -1):
        vp_idx = p_vc_sorted[v_idx, cls]
        vp = dataset.vps[vp_idx]

        verb_idx = dataset.vs_dict[vp[0]]
        p_idx = dataset.ps_dict[vp[1]]
        
        if (data_model.p_vc[verb_idx, cls] / 1000.) >= 1:
       
            row = '\\' + " {0:.6f}".format(round(data_model.p_vc[verb_idx, cls], 6)) + ' & \\verb|' + str('.'.join(vp)) + "|  "
        else:
            row = '\\' + '%.2E'%(data_model.p_vc[verb_idx, cls]) + ' & \\verb|' + str('.'.join(vp)) + "|  "
        for n_idx in range(19, -1, -1):
            noun_idx = p_nc_sorted[n_idx, cls]
            if (vp_idx,noun_idx,  verb_idx,  p_idx) in dataset.ys_dict:
                row += '& $\\bigcdot$  '
            else:
                row += "&    "

        rows.append(row)
    return "\\\\ ".join(rows)

def make_top_rows(p_nc_sorted, data_model, cls=0, prob=0):
    row1 = "\\begin{tabular}[c]{@{}l@{}}Class "+ str(cls + 1) +"\\ PROB  " + str(round(prob,6)) +  "\end{tabular} &     "
    row2 = "&     "
    for n_idx in range(19,-1,-1):
        noun_idx = p_nc_sorted[n_idx,cls]
        row1 +=    "&       \\rotatebox[origin=c]{90}{      " + str(round(data_model.p_nc[noun_idx,cls],6)) + "    }     "
        row2 += "&     \\rotatebox[origin=c]{90}{    " + dataset.ns[noun_idx] + "      }     "
    row1 += " \\\\" + " \\hline"
    row2 += " \\\\" + " \\hline"
    return row1 + "\n" +  row2

def table_bottom():
    return "\\\\ \n" + "\hline \n" + "\end{tabular} \n" +  "\end{adjustbox} \n" +"\end{table} \n"

def table_top(caption = "My caption", label="my-label"):
    return "\\begin{table}[] \n" + "\centering  \n" +  "\caption{"+ caption +"} \n" +  "\label{" + label +"} \n"  \
            + "\\begin{adjustbox}{max width=\\textwidth} \n" +  "\\begin{tabular}{|l|l|llllllllllllllllllll|} \n" + "\hline"

# %%
#for cls in range(0,10):



def print_table(caption, label, cls, p_nc_sorted, p_vc_sorted , data_model ):
    top  = table_top(caption, label)
    #print top
    top_rows =  make_top_rows(p_nc_sorted, data_model, cls, data_model.p_c[cls])
    #print top_rows
    middle_rows = make_table_rows(dataset, p_vc_sorted, p_nc_sorted, cls)
    #print middle_rows
    bottom = table_bottom()
    #print bottom
    print (top + top_rows + middle_rows + bottom)
    
    
    
cls = 50 # note that it is cls -1
caption = "My caption"
label="my-label"
print_table(caption, label, cls, p_nc_sorted, p_vc_sorted , data_model )
# Out:
# \begin{table}[]
# \centering
# \caption{My caption}
# \label{my-label}
# \begin{adjustbox}{max width=\textwidth}
# \begin{tabular}{|l|l|llllllllllllllllllll|}
# \hline\begin{tabular}[c]{@{}l@{}}Class 51\ PROB  0.003367\end{tabular} &     &       \rotatebox[origin=c]{90}{      0.029915    }     &       \rotatebox[origin=c]{90}{      0.024754    }     &       \rotatebox[origin=c]{90}{      0.020325    }     &       \rotatebox[origin=c]{90}{      0.018831    }     &       \rotatebox[origin=c]{90}{      0.01585    }     &       \rotatebox[origin=c]{90}{      0.014643    }     &       \rotatebox[origin=c]{90}{      0.013457    }     &       \rotatebox[origin=c]{90}{      0.013054    }     &       \rotatebox[origin=c]{90}{      0.012269    }     &       \rotatebox[origin=c]{90}{      0.01221    }     &       \rotatebox[origin=c]{90}{      0.011978    }     &       \rotatebox[origin=c]{90}{      0.011822    }     &       \rotatebox[origin=c]{90}{      0.011378    }     &       \rotatebox[origin=c]{90}{      0.010495    }     &       \rotatebox[origin=c]{90}{      0.008701    }     &       \rotatebox[origin=c]{90}{      0.00852    }     &       \rotatebox[origin=c]{90}{      0.007916    }     &       \rotatebox[origin=c]{90}{      0.007712    }     &       \rotatebox[origin=c]{90}{      0.007675    }     &       \rotatebox[origin=c]{90}{      0.007021    }      \\ \hline
# &     &     \rotatebox[origin=c]{90}{    feet      }     &     \rotatebox[origin=c]{90}{    leaves      }     &     \rotatebox[origin=c]{90}{    smoke      }     &     \rotatebox[origin=c]{90}{    hair      }     &     \rotatebox[origin=c]{90}{    leaving      }     &     \rotatebox[origin=c]{90}{    dust      }     &     \rotatebox[origin=c]{90}{    lip      }     &     \rotatebox[origin=c]{90}{    memory      }     &     \rotatebox[origin=c]{90}{    streets      }     &     \rotatebox[origin=c]{90}{    fighting      }     &     \rotatebox[origin=c]{90}{    leave      }     &     \rotatebox[origin=c]{90}{    branches      }     &     \rotatebox[origin=c]{90}{    boards      }     &     \rotatebox[origin=c]{90}{    visit      }     &     \rotatebox[origin=c]{90}{    teeth      }     &     \rotatebox[origin=c]{90}{    grass      }     &     \rotatebox[origin=c]{90}{    ice      }     &     \rotatebox[origin=c]{90}{    toes      }     &     \rotatebox[origin=c]{90}{    brush      }     &     \rotatebox[origin=c]{90}{    caring      }      \\ \hline\2.64E-34 & \verb|cut.so_dobj|  &    & $\bigcdot$  &    & $\bigcdot$  &    &    &    &    &    &    &    & $\bigcdot$  &    & $\bigcdot$  & $\bigcdot$  & $\bigcdot$  & $\bigcdot$  &    &    &    \\ \2.64E-34 & \verb|cut.o_dobj|  &    &    &    & $\bigcdot$  &    &    & $\bigcdot$  &    &    &    &    &    & $\bigcdot$  &    &    & $\bigcdot$  &    &    &    &    \\ \3.59E-17 & \verb|paid.so_dobj|  &    &    &    &    &    &    &    &    &    &    &    &    &    & $\bigcdot$  &    &    &    &    &    &    \\ \4.74E-70 & \verb|remov.oo_dobj|  &    & $\bigcdot$  &    &    &    & $\bigcdot$  &    &    &    & $\bigcdot$  &    &    &    &    &    &    & $\bigcdot$  &    & $\bigcdot$  &    \\ \1.71E-55 & \verb|leav.os_csubj|  &    & $\bigcdot$  &    &    & $\bigcdot$  &    &    &    &    &    & $\bigcdot$  &    &    &    &    &    &    &    &    &    \\ \2.76E-77 & \verb|paint.so_dobj|  &    &    &    & $\bigcdot$  &    &    &    &    &    &    &    &    &    &    &    & $\bigcdot$  &    &    &    &    \\ \2.33E-103 & \verb|brush.so_dobj|  & $\bigcdot$  &    &    & $\bigcdot$  &    & $\bigcdot$  &    & $\bigcdot$  &    &    &    &    &    &    & $\bigcdot$  &    &    &    &    &    \\ \3.62E-39 & \verb|fight.o_dobj|  &    &    &    &    &    &    &    &    &    & $\bigcdot$  &    &    &    &    &    &    &    &    &    &    \\ \0.00E+00 & \verb|peg.s_nsubj|  &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    \\ \0.00E+00 & \verb|bit.so_dobj|  &    &    &    &    &    & $\bigcdot$  & $\bigcdot$  &    &    &    &    &    &    &    &    &    &    &    &    &    \\ \9.21E-41 & \verb|tore.so_dobj|  &    &    &    & $\bigcdot$  &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    \\ \3.82E-38 & \verb|compris.oooo_dobj|  &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    & $\bigcdot$  &    &    &    &    \\ \0.00E+00 & \verb|blew.so_dobj|  &    &    & $\bigcdot$  & $\bigcdot$  &    & $\bigcdot$  &    &    &    &    &    &    &    &    &    &    &    &    &    &    \\ \1.71E-55 & \verb|leav.s_csubj|  &    & $\bigcdot$  &    &    & $\bigcdot$  &    &    &    &    &    & $\bigcdot$  &    &    &    &    &    &    &    &    &    \\ \5.92E-06 & \verb|blow.so_dobj|  &    &    & $\bigcdot$  &    &    & $\bigcdot$  &    &    &    &    &    &    &    &    &    &    &    &    &    &    \\ \5.28E-318 & \verb|stamp.so_dobj|  & $\bigcdot$  &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    \\ \1.26E-54 & \verb|tie.so_dobj|  &    &    &    & $\bigcdot$  &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    \\ \1.26E-54 & \verb|tie.o_dobj|  &    &    &    & $\bigcdot$  &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    &    \\ \1.20E-38 & \verb|fix.o_dobj|  &    &    &    &    &    &    &    &    &    &    &    &    &    &   ...
# \hline
# \end{tabular}
# \end{adjustbox}
# \end{table}

# %%
for cls in range (0, data_model.n_cs):
    verb_list = []
    noun_list = []
    for word in range(19,-1,-1):
        try:
            verb_idx = p_vc_sorted[word,cls] 
            noun_idx = p_nc_sorted[word,cls]


            verb = dataset.vps[verb_idx]
            noun = dataset.ns[noun_idx]

            verb_list.append("_".join(verb))
            noun_list.append(noun)
        except:
            print ("error")
            break
    
    if len(verb_list) == 20 and len(noun_list) == 20:
        print ("Class: %i"%(cls +1))
        print ("Verbs:")
        print (verb_list)
        print ("Nouns:")
        print (noun_list)
        
        print ("\n\n")
    else:
        print  ("Class: %i"%(cls +1))
# Out:
# Class: 1
# Verbs:
# ["'s_s_nsubj", 'make_so_nsubj', 'follow_s_nsubj', 'run_s_nsubj', 'happen_s_nsubj', 'rose_so_nsubj', 'exist_s_nsubj', 'come_s_nsubj', 'run_so_nsubj', 'serv_so_nsubj', 'go_s_nsubj', 'take_so_nsubj', 'help_so_nsubj', 'goe_s_nsubj', 'matter_s_nsubj', 'remain_s_nsubj', 'went_s_nsubj', 'aris_s_nsubj', 'look_s_nsubj', 'leav_so_nsubj']
# Nouns:
# ['that', 'it', 'wind', 'manufacturers', 'characters', 'the', 'gangs', 'argument', 'dog', 'heat', 'cut', 'suitable', 'fate', 'others', 'feelings', 'emotions', 'fear', 'parts', 'images', 'lights']
#
#
#
# Class: 2
# Verbs:
# ['fell_s_nsubj', 'rose_s_nsubj', 'rise_s_nsubj', 'fall_s_nsubj', 'rose_so_nsubj', 'beat_so_dobj', 'fell_so_nsubj', 'amount_s_nsubj', 'increas_so_dobj', 'drop_s_nsubj', 'win_so_nsubj', 'go_s_nsubj', 'reach_so_nsubj', 'cut_so_dobj', 'jump_so_nsubj', 'saw_so_dobj', 'soar_s_nsubj', 'doubl_s_nsubj', 'contain_soo_dobj', 'win_s_nsubj']
# Nouns:
# ['all', 'prices', 'profits', 'shares', 'earnings', 'number', 'net', 'writing', 'sales', 'profit', 'rate', 'rates', 'index', 'production', 'words', 'share', 'pound', 'price', 'temperature', 'income']
#
#
#
# Class: 3
# Verbs:
# ['said_so_csubj', 'go_s_csubj', 'come_s_csubj', 'talk_s_csubj', 'take_so_csubj', 'go_o_dobj', 'got_so_csubj', 'make_so_csubj', 'think_s_csubj', 'depend_s_csubj', 'walk_s_csubj', 'mean_so_csubj', 'wa_s_csubj', 'produc_so_csubj', 'chang_os_csubj', 'ha_so_csubj', 'requir_so_csubj', 'look_s_csubj', 'give_soo_csubj', 'say_so_csubj']
# Nouns:
# ['going', 'go', 'have', 'do', 'come', 'changing', 'thinking', 'did', 'talking', 'let', 'had', 'is', 'will', 'think', 'can', 'does', 'has', 'applying', 'get', 'look']
#
#
#
# Class: 4
# Verbs:
# ['produc_so_dobj', 'chang_so_dobj', 'know_so_dobj', 'creat_so_dobj', 'chang_s_nsubj', 'adopt_so_dobj', 'reveal_so_dobj', 'rememb_so_dobj', 'set_so_dobj', 'see_so_dobj', 'follow_so_dobj', 'explain_so_dobj', 'examin_so_dobj', 'describ_so_dobj', 'chang_o_dobj', 'reflect_so_dobj', 'record_so_dobj', 'alter_so_dobj', 'emerg_s_nsubj', 'prevent_so_dobj']
# Nouns:
# ['world', 'situation', 'pattern', 'them', 'nature', 'results', 'image', 'evidence', 'patterns', 'policy', 'attitude', 'style', 'tone', 'design', 'mind', 'subject', 'approach', 'name', 'problems', 'effects']
#
#
#
# Class: 5
# Verbs:
# ['made_so_nsubj', 'join_so_dobj', 'face_so_nsubj', 'play_s_nsubj', 'began_so_nsubj', 'express_so_nsubj', 'score_so_nsubj', 'play_so_nsubj', 'took_so_nsubj', 'releas_so_nsubj', 'score_s_nsubj', 'succeed_s_nsubj', 'compet_s_nsubj', 'built_so_nsubj', 'march_s_nsubj', 'led_so_dobj', 'fled_s_nsubj', 'escap_s_nsubj', 'organis_so_nsubj', 'respond_s_nsubj']
# Nouns:
# ['they', 'he', 'army', 'forces', 'who', 'england', 'band', 'group', 'workers', 'party', 'troops', 'leaders', 'palace', 'team', 'club', 'police', 'company', 'united', 'side', 'force']
#
#
#
# Class: 6
# Verbs:
# ['turn_so_dobj', 'manag_o_dobj', 'turn_o_dobj', 'join_soo_dobj', 'listen_s_csubj', 'get_ss_nsubj', 'drive_so_nsubj', 'tell_sso_nsubj', 'stick_s_nsubj', 'underw_so_dobj', 'find_sso_nsubj', 'hang_o_dobj', 'came_sss_nsubj', 'advis_so_dobj', 'refer_ss_nsubj', 'cost_sooo_dobj', 'smell_s_nsubj', 'cf._o_dobj', 'continu_s_csubj', 'cost_soooo_dobj']
# Nouns:
# ['round', 'back', 'corner', 'listening', 'director', 'young', 'villages', 'towns', 'stomach', 'sons', 'backs', 'agent', 'tables', 'daughters', 'bullet', 'continue', 'listen', 'feature', 'funding', 's']
#
#
#
# Class: 7
# Verbs:
# ['wear_so_dobj', 'wore_so_dobj', 'wear_o_dobj', 'wear_soo_dobj', 'wore_soo_dobj', 'wear_oo_dobj', 'form_sso_nsubj', 'wear_sooo_dobj', 'discov_so_dobj', 'want_oss_csubj', 'buy_o_dobj', 'contain_soooo_dobj', 'ad_os_csubj', 'found_soo_dobj', 'wore_sooo_dobj', 'stand_s_csubj', 'sport_so_dobj', 'pull_so_dobj', 'remov_so_dobj', 'design_so_dobj']
# Nouns:
# ['clothes', 'dress', 'suit', 'want', 'jacket', 'hat', 'coat', 'shoes', 'shirt', 'check', 'boots', 'adding', 'trousers', 'remember', 'standing', 'save', 'setting', 'tie', 'cap', 'glasses']
#
#
#
# Class: 8
# Verbs:
# ['includ_soo_dobj', 'receiv_so_dobj', 'drew_so_dobj', 'draw_so_dobj', 'bear_so_dobj', 'includ_sooooooo_dobj', 'attract_so_dobj', 'receiv_soo_dobj', 'bear_o_dobj', 'bore_so_dobj', 'draw_o_dobj', 'turn_so_dobj', 'resist_so_dobj', 'deserv_so_dobj', 'pay_o_dobj', 'pay_so_dobj', 'appear_so_dobj', 'requir_so_dobj', 'note_o_dobj', 'escap_so_dobj']
# Nouns:
# ['attention', 'eyes', 'resemblance', 'flowers', 'name', 'bottle', 'set', 'type', 'temptation', 'nose', 'support', 'witness', 'existing', 'relation', 'treatment', 'line', 'bar', 'letter', 'training', 'fruit']
#
#
#
# Class: 9
# Verbs:
# ['continu_s_nsubj', 'start_s_nsubj', 'start_so_dobj', 'begin_s_nsubj', 'began_s_nsubj', 'began_so_dobj', 'continu_so_dobj', 'complet_so_dobj', 'took_so_nsubj', 'follow_so_dobj', 'end_s_nsubj', 'begin_so_dobj', 'face_so_dobj', 'involv_so_dobj', 'describ_so_dobj', 'involv_soo_dobj', 'conduct_so_dobj', 'stop_so_dobj', 'end_so_dobj', 'go_s_nsubj']
# Nouns:
# ['work', 'process', 'life', 'career', 'search', 'trial', 'programme', 'campaign', 'research', 'learning', 'debate', 'series', 'investigation', 'hearing', 'discussion', 'war', 'sale', 'tour', 'efforts', 'course']
#
#
#
# Class: 10
# Verbs:
# ['ha_so_nsubj', 'come_s_nsubj', 'take_so_nsubj', 'took_so_nsubj', 'doe_s_nsubj', 'happen_s_nsubj', 'believ_so_dobj', 'put_so_dobj', 'make_so_nsubj', 'go_s_nsubj', 'gave_so_nsubj', "'s_s_nsubj", 'made_so_nsubj', 'matter_s_nsubj', 'provid_so_nsubj', 'appear_s_nsubj', 'wa_os_nsubj', 'get_so_dobj', 'take_s_nsubj', 'ha_soo_nsubj']
# Nouns:
# ['it', 'sun', 'cat', 'luck', 'one', 'good', 'shot', 'bird', 'moon', 'star', 'ears', 'ball', 'thatcher', 'the', 'work', 'heart', 'vines', 'critic', 'mean', 'madonna']
#
#
#
# Class: 11
# Verbs:
# ['add_oo_dobj', 'add_o_dobj', 'say_o_dobj', 'add_ooo_dobj', 'see_soo_dobj', 'saw_soo_dobj', 'produc_sso_nsubj', 'offer_sso_nsubj', 'lead_o_dobj', 'like_soo_dobj', 'add_oooo_dobj', 'build_so_dobj', 'wa_so_dobj', 'serv_soo_dobj', 'add_sooo_dobj', 'introduc_soo_dobj', 'cook_o_dobj', 'melt_o_dobj', 'smoke_so_dobj', 'visit_sooo_dobj']
# Nouns:
# ['have', 'cook', 'salt', 'cream', 'was', 'roll', 'butter', 'vegetables', 'society', 'sugar', 'tell', 'potatoes', 'put', 'pepper', 'rock', 'beans', 'houses', 'onion', 'rice', 'cheese']
#
#
#
# Class: 12
# Verbs:
# ['move_s_nsubj', 'disappear_s_nsubj', 'work_o_dobj', 'establish_so_nsubj', 'fli_s_nsubj', 'settl_s_nsubj', 'work_s_csubj', 'move_so_nsubj', 'play_soo_dobj', 'gave_sso_nsubj', 'block_so_nsubj', 'move_s_csubj', 'gather_s_nsubj', 'grow_o_dobj', 'jog_s_nsubj', 'split_s_nsubj', 'breed_s_nsubj', 'take_ssso_nsubj', 'build_s_nsubj', 'commun_s_nsubj']
# Nouns:
# ['family', 'working', 'party', 'horses', 'moving', 'minister', 'today', 'germany', 'clouds', 'breeding', 'individuals', 'creatures', 'brown', 'candidates', 'd', 'market', 'men', 'any', 'growing', 'work']
#
#
#
# Class: 13
# Verbs:
# ['includ_soooo_dobj', 'ha_soo_dobj', 'make_sso_nsubj', 'find_soo_dobj', 'show_sso_nsubj', 'compris_sooo_dobj', 'give_ssoo_nsubj', 'see_os_csubj', 'creat_sso_nsubj', 'compris_soo_dobj', 'fight_so_dobj', 'find_sooo_dobj', 'sat_so_dobj', 'follow_soo_dobj', 'bought_soo_dobj', 'see_oss_csubj', 'incorpor_so_dobj', 'fought_so_dobj', 'check_o_dobj', 'see_s_csubj']
# Nouns:
# ['see', 'seeing', 'management', 'control', 'equipment', 'buildings', 'battle', 'security', 'paintings', 'bar', 'boxes', 'found', 'drawings', 'each', 'weaknesses', 'finish', 'upright', 'start', 'lurking', 'welcome']
#
#
#
# Class: 14
# Verbs:
# ['contain_so_nsubj', 'give_soo_nsubj', 'doe_so_dobj', 'use_so_dobj', 'bought_so_dobj', 'cost_so_nsubj', 'tri_o_dobj', 'tri_so_dobj', 'sound_s_nsubj', 'want_so_dobj', 'ha_so_nsubj', 'know_so_dobj', 'goe_s_nsubj', 'take_so_nsubj', 'like_so_dobj', 'provid_soo_nsubj', 'use_o_dobj', 'doe_o_dobj', 'start_s_nsubj', 'provid_so_nsubj']
# Nouns:
# ['it', 'this', 'line', 'one', 'each', 'house', 'word', 'work', 'job', 'best', 'some', 'names', 'book', 'company', 'section', 'painting', 'not', 'speaking', 'business', 'club']
#
#
#
# Class: 15
# Verbs:
# ['send_so_dobj', 'send_o_dobj', 'sent_so_dobj', 'take_os_csubj', 'send_oo_dobj', 'sent_soo_dobj', 'send_soo_dobj', 'depend_s_csubj', 'possess_so_dobj', 'wrote_ss_nsubj', 'sign_so_dobj', 'ad_sso_nsubj', 'enclos_so_dobj', 'take_s_csubj', 'enclos_o_dobj', 'return_o_dobj', 'transmit_so_dobj', 'sign_o_dobj', 'complet_o_dobj', 'boast_soo_dobj']
# Nouns:
# ['taking', 'take', 'message', 'details', 'copy', 'card', 'sae', 'messages', 'form', 'coupon', 'signals', 'name', 'address', 'cheque', 'waves', 'tapes', 'letter', 'postcard', 'letters', 'departure']
#
#
#
# Class: 16
# Verbs:
# ['follow_so_nsubj', 'hold_so_nsubj', 'pass_s_nsubj', 'call_s_nsubj', 'follow_so_dobj', 'mark_so_nsubj', 'reach_so_nsubj', 'follow_o_dobj', 'cross_so_nsubj', 'took_so_nsubj', 'take_s_nsubj', 'save_so_nsubj', 'await_so_dobj', 'lead_s_nsubj', 'suppli_so_nsubj', 'run_s_nsubj', 'saw_so_nsubj', 'end_s_nsubj', 'surviv_so_nsubj', 'bring_soo_nsubj']
# Nouns:
# ['road', 'years', 'route', 'path', 'track', 'decision', 'marriage', 'repeat', 'line', 'arrival', 'tour', 'day', 'boats', 'coach', 'move', 'week', 'attacks', 'period', 'stream', 'DIGIT']
#
#
#
# Class: 17
# Verbs:
# ['said_ss_nsubj', 'announc_so_nsubj', 'gave_soo_nsubj', 'join_so_nsubj', 'rais_so_nsubj', 'took_sso_nsubj', 'issu_so_nsubj', 'contact_so_dobj', 'propos_so_nsubj', 'die_so_nsubj', 'manag_so_dobj', 'order_so_nsubj', 'admit_s_nsubj', 'enjoy_sso_nsubj', 'gave_so_nsubj', 'took_so_nsubj', 'promis_so_nsubj', 'come_soo_dobj', 'featur_ooo_dobj', 'recommend_so_nsubj']
# Nouns:
# ['group', 'commission', 'secretary', 'manager', 'britain', 'director', 'committee', 'president', 'chairman', 'lewis', 'prince', 'government', 'thanks', 'co', 'company', 'minister', 'council', 'anne', 'b', 'chancellor']
#
#
#
# Class: 18
# Verbs:
# ['spent_so_dobj', 'spend_so_dobj', 'contain_o_dobj', 'sell_so_dobj', 'buy_so_dobj', 'contain_so_dobj', 'produc_so_dobj', 'sold_so_dobj', 'collect_so_dobj', 'sell_o_dobj', 'suppli_so_dobj', 'wast_so_dobj', 'buy_o_dobj', 'spend_o_dobj', 'carri_so_dobj', 'contain_sooo_dobj', 'hold_so_dobj', 'bought_so_dobj', 'last_so_dobj', 'collect_o_dobj']
# Nouns:
# ['time', 'water', 'hours', 'most', 'money', 'food', 'days', 'information', 'goods', 'lot', 'energy', 'years', 'much', 'them', 'amount', 'oil', 'amounts', 'day', 'deal', 'rest']
#
#
#
# Class: 19
# Verbs:
# ['pay_so_nsubj', 'appli_s_nsubj', 'meet_s_nsubj', 'differ_s_nsubj', 'produc_s_nsubj', 'paid_so_nsubj', 'possess_so_nsubj', 'react_s_nsubj', 'exhibit_so_nsubj', 'affect_soo_dobj', 'use_so_nsubj', 'make_os_nsubj', 'repres_o_dobj', 'swim_s_nsubj', 'receiv_s_nsubj', 'invest_so_nsubj', 'carri_sso_nsubj', 'includ_sooooo_nsubj', 'benefit_so_dobj', 'involv_o_dobj']
# Nouns:
# ['companies', 'members', 'countries', 'guests', 'building', 'many', 'species', 'same', 'individual', 'teams', 'supporters', 'opinions', 'rules', 'group', 'university', 'company', 'organization', 'star', 'organisation', 'animals']
#
#
#
# Class: 20
# Verbs:
# ['acquir_so_nsubj', 'surround_o_dobj', 'think_so_dobj', 'get_os_csubj', 'get_s_csubj', 'accus_so_nsubj', 'earn_so_nsubj', 'brought_s_nsubj', 'struck_so_nsubj', 'weigh_so_nsubj', 'speak_o_dobj', 'bound_s_nsubj', 'spare_so_dobj', 'heard_soo_dobj', 'get_oss_csubj', 'declin_so_nsubj', 'arrang_soo_dobj', 'spare_o_dobj', 'recognis_sso_nsubj', 'rescu_so_nsubj']
# Nouns:
# ['thought', 'getting', 'thoughts', 'get', 'new', 'strikes', 'agencies', 'cameras', 'hull', 'cry', 'oath', 'obtaining', 'partner', 'scots', 'kinnock', 'critics', 'riots', 'hundred', 'lightning', 'hens']
#
#
#
# Class: 21
# Verbs:
# ["'s_s_nsubj", 'say_so_dobj', 'wa_s_nsubj', 'know_so_dobj', 'said_so_dobj', 'ha_so_dobj', 'see_so_dobj', 'knew_so_dobj', 'happen_s_nsubj', 'mean_so_dobj', 'learn_so_dobj', 'got_so_dobj', 'want_so_dobj', 'doe_so_dobj', 'say_o_dobj', 'tell_soo_dobj', 'saw_so_dobj', 'rememb_so_dobj', 'get_so_dobj', 'meant_so_dobj']
# Nouns:
# ['nothing', 'something', 'things', 'lot', 'anything', 'thing', 'name', 'all', 'word', 'one', 'everything', 'more', 'deal', 'no', 'little', 'way', 'words', 'time', 'reason', 'none']
#
#
#
# Class: 22
# Verbs:
# ['open_so_dobj', 'use_so_nsubj', 'open_s_nsubj', 'close_so_dobj', 'launch_so_nsubj', 'held_so_nsubj', 'close_s_nsubj', 'open_o_dobj', 'met_s_nsubj', 'seek_so_nsubj', 'sold_so_nsubj', 'spent_so_nsubj', 'report_s_nsubj', 'accept_so_nsubj', 'shut_so_dobj', 'maintain_so_nsubj', 'close_o_dobj', 'argu_s_nsubj', 'sign_so_nsubj', 'beat_so_nsubj']
# Nouns:
# ['door', 'eyes', 'doors', 'inc', 'mouth', 'window', 'gates', 'gate', 'exhibition', 'fire', 'group', 'gallery', 'committee', 'it', 'shop', 'unions', 'windows', 'railway', 'ibm', 'company']
#
#
#
# Class: 23
# Verbs:
# ['provid_so_dobj', 'form_so_dobj', 'includ_sooooo_dobj', 'ad_so_dobj', 'form_o_dobj', 'provid_o_dobj', 'ad_o_dobj', 'constitut_so_dobj', 'provid_sso_dobj', 'add_so_dobj', 'provid_soo_dobj', 'repres_so_dobj', 'releas_so_dobj', 'contain_so_dobj', 'press_so_dobj', 'form_sso_dobj', 'mean_soo_dobj', 'mean_oss_csubj', 'add_o_dobj', 'produc_sooo_dobj']
# Nouns:
# ['information', 'basis', 'part', 'hair', 'means', 'skin', 'source', 'evidence', 'framework', 'example', 'turn', 'model', 'opportunity', 'button', 'base', 'turning', 'mean', 'foundation', 'link', 'data']
#
#
#
# Class: 24
# Verbs:
# ['call_so_dobj', 'ask_so_dobj', 'said_s_nsubj', 'met_so_dobj', 'spoke_s_nsubj', 'visit_so_dobj', 'die_s_nsubj', 'saw_so_dobj', 'took_so_nsubj', 'see_so_dobj', 'gave_so_nsubj', 'appear_ss_nsubj', 'threw_so_nsubj', 'told_so_nsubj', 'ask_so_nsubj', 'gave_soo_nsubj', 'shout_s_nsubj', 'got_so_nsubj', 'live_ss_nsubj', 'call_soo_dobj']
# Nouns:
# ['man', 'mother', 'father', 'woman', 'wife', 'dad', "'s", 'husband', 'mum', 'police', 'one', 'charles', 'friend', 'captain', 'jesus', 'doctor', 'girl', 'smith', 'leader', 'david']
#
#
#
# Class: 25
# Verbs:
# ['take_so_nsubj', 'support_so_nsubj', 'took_so_nsubj', 'make_so_nsubj', 'claim_so_nsubj', 'want_so_nsubj', 'look_s_nsubj', 'believ_s_nsubj', 'came_s_nsubj', 'belong_s_nsubj', 'show_so_nsubj', 'provid_so_nsubj', 'kill_so_nsubj', 'made_so_nsubj', 'own_so_nsubj', 'sent_so_nsubj', 'live_so_nsubj', 'work_so_nsubj', 'gave_soo_nsubj', 'hold_so_nsubj']
# Nouns:
# ['who', 'they', 'he', 'which', 'it', 'i', 'government', 'most', 'that', 'company', 'she', 'some', 'members', 'many', 'group', 'council', 'britain', 'party', 'we', 'neither']
#
#
#
# Class: 26
# Verbs:
# ['rais_so_dobj', 'remain_s_nsubj', 'face_so_dobj', 'contain_so_dobj', 'aris_s_nsubj', 'support_so_dobj', 'pose_so_dobj', 'ask_so_dobj', 'introduc_so_dobj', 'answer_so_dobj', 'present_so_dobj', 'address_so_dobj', 'solv_so_dobj', 'support_o_dobj', 'aros_s_nsubj', 'rais_o_dobj', 'support_soo_dobj', 'produc_o_dobj', 'consid_so_dobj', 'discuss_so_dobj']
# Nouns:
# ['question', 'questions', 'problems', 'problem', 'issues', 'issue', 'some', 'difficulties', 'fears', 'systems', 'threat', 'call', 'future', 'difficulty', 'number', 'possibility', 'eyebrows', 'stars', 'matter', 'matters']
#
#
#
# Class: 27
# Verbs:
# ['ha_so_nsubj', 'watch_o_dobj', 'watch_so_dobj', 'ha_soo_nsubj', 'ha_sooo_nsubj', 'ha_s_nsubj', 'show_soo_nsubj', 'ha_sso_nsubj', 'explain_s_nsubj', 'doe_so_nsubj', 'ha_soooo_nsubj', 'share_o_dobj', 'order_so_dobj', 'keep_so_nsubj', 'deriv_s_nsubj', 'boast_so_nsubj', 'rule_so_dobj', 'move_so_nsubj', 'indic_sso_nsubj', 'combin_s_nsubj']
# Nouns:
# ['he', 'it', 'she', 'who', 'this', 'hotel', 'one', 'television', 'each', 'company', 'film', 'britain', 'everyone', 'group', 'system', 'uk', 'government', 'person', 'model', 'which']
#
#
#
# Class: 28
# Verbs:
# ['said_s_nsubj', 'found_so_nsubj', 'told_so_nsubj', 'led_so_nsubj', 'wrote_s_nsubj', 'bought_so_nsubj', 'want_so_nsubj', 'took_s_nsubj', 'drew_so_nsubj', 'dismiss_so_nsubj', 'went_so_nsubj', 'resign_s_nsubj', 'defend_so_nsubj', 'chose_so_nsubj', 'direct_so_nsubj', 'comment_s_nsubj', 'gave_so_nsubj', 'gave_s_nsubj', 'stand_so_nsubj', 'remark_s_nsubj']
# Nouns:
# ['he', 'she', 'who', 'i', 'they', 'spokesman', 'diana', 'nicholas', 'police', 'chairman', 'minister', 'charles', 'company', 'parker', 'pope', 'miller', 'boss', 'friend', 'inspectors', 'officer']
#
#
#
# Class: 29
# Verbs:
# ['said_so_dobj', 'said_o_dobj', 'ask_o_dobj', 'celebr_so_dobj', 'said_s_nsubj', 'went_ss_nsubj', 'look_ss_nsubj', 'shout_o_dobj', 'look_s_nsubj', 'ask_so_dobj', 'say_o_dobj', 'thought_o_dobj', 'demand_o_dobj', 'shout_so_dobj', 'said_sso_dobj', 'celebr_o_dobj', 'cri_o_dobj', 'enquir_o_dobj', 'repli_o_dobj', 'saw_so_dobj']
# Nouns:
# ['philip', 'jack', 'joe', 'lee', 'tom', 'jay', 'henry', 'masklin', 'angalo', 'anniversary', 'endill', 'voice', 'goodbye', 'man', 'dolly', 'birthday', 'gurder', 'marie', 'breeze', 'lucy']
#
#
#
# Class: 30
# Verbs:
# ['includ_sooo_dobj', 'caus_so_dobj', 'reach_so_dobj', 'suffer_so_dobj', 'feel_so_dobj', 'express_so_dobj', 'caus_o_dobj', 'caus_soo_dobj', 'felt_so_dobj', 'indic_so_dobj', 'suggest_so_dobj', 'creat_so_dobj', 'experienc_so_dobj', 'experi_so_dobj', 'surviv_so_dobj', 'mean_so_dobj', 'provok_so_dobj', 'avoid_o_dobj', 'involv_so_dobj', 'prevent_so_dobj']
# Nouns:
# ['problems', 'need', 'damage', 'loss', 'concern', 'pain', 'death', 'bed', 'breakfast', 'dinner', 'feelings', 'fear', 'change', 'finding', 'injury', 'desire', 'difficulties', 'tension', 'disease', 'end']
#
#
#
# Class: 31
# Verbs:
# ['give_so_dobj', 'give_soo_dobj', 'gave_soo_dobj', 'gave_so_dobj', 'get_so_dobj', 'got_so_dobj', 'give_o_dobj', 'receiv_so_dobj', 'give_oo_dobj', 'offer_so_dobj', 'provid_so_dobj', 'want_so_dobj', 'seek_so_dobj', 'gain_so_dobj', 'get_o_dobj', 'obtain_so_dobj', 'offer_soo_dobj', 'requir_so_dobj', 'came_s_nsubj', 'seek_o_dobj']
# Nouns:
# ['support', 'chance', 'help', 'advice', 'rise', 'information', 'opportunity', 'access', 'money', 'impression', 'name', 'details', 'job', 'time', 'look', 'credit', 'idea', 'birth', 'one', 'results']
#
#
#
# Class: 32
# Verbs:
# ['found_so_dobj', 'find_so_dobj', 'leav_o_dobj', 'replac_so_dobj', 'like_so_dobj', 'love_so_dobj', 'leav_so_dobj', 'see_so_dobj', 'move_so_dobj', 'threw_so_dobj', 'walk_so_dobj', 'pass_so_dobj', 'enjoy_so_dobj', 'describ_so_dobj', 'hate_so_dobj', 'saw_so_dobj', 'present_so_dobj', 'move_o_dobj', 'regard_so_dobj', 'swung_so_dobj']
# Nouns:
# ['himself', 'themselves', 'itself', 'round', 'herself', 'myself', 'them', 'yourself', 'it', 'ourselves', 'body', 'him', 'horse', 'past', 'legs', 'her', 'one', 'company', 'glass', 'support']
#
#
#
# Class: 33
# Verbs:
# ['came_s_nsubj', 'sat_s_nsubj', 'laugh_s_nsubj', 'look_s_nsubj', 'nod_s_nsubj', 'stay_s_nsubj', 'shook_so_nsubj', 'ask_s_nsubj', 'cri_s_nsubj', 'stare_s_nsubj', 'went_s_nsubj', 'ask_so_nsubj', 'smile_s_nsubj', 'listen_s_nsubj', 'scream_s_nsubj', 'watch_so_nsubj', 'said_so_nsubj', 'said_ss_nsubj', 'walk_s_nsubj', 'said_s_nsubj']
# Nouns:
# ['she', 'i', 'they', 'girl', 'no', 'man', 'willie', 'men', 'mother', 'woman', 'everyone', 'sarah', 'crowd', 'children', 'girls', 'maggie', 'peter', 'matilda', 'billy', 'philip']
#
#
#
# Class: 34
# Verbs:
# ['went_s_nsubj', 'return_s_nsubj', 'came_s_nsubj', 'made_so_nsubj', 'left_s_nsubj', 'got_so_nsubj', 'wrote_s_nsubj', 'made_s_nsubj', 'chang_so_nsubj', 'ad_so_nsubj', 'drop_so_nsubj', 'spent_s_nsubj', 'tri_s_nsubj', 'saw_so_nsubj', 'reach_so_nsubj', 'join_so_nsubj', 'hit_so_nsubj', 'carri_s_nsubj', 'land_s_nsubj', 'call_so_nsubj']
# Nouns:
# ['he', 'they', 'she', 'we', 'i', 'who', 'it', 'company', 'men', 'you', 'all', 'one', 'smith', 'most', 'chapman', 'family', 'party', 'john', 'aircraft', 'some']
#
#
#
# Class: 35
# Verbs:
# ['know_s_nsubj', 'think_s_nsubj', 'got_so_nsubj', 'saw_so_nsubj', 'see_so_nsubj', 'go_s_nsubj', 'look_s_nsubj', 'like_so_nsubj', 'went_s_nsubj', 'ask_so_nsubj', 'see_s_nsubj', 'rememb_so_nsubj', 'know_so_nsubj', 'want_so_nsubj', 'get_so_nsubj', 'love_so_nsubj', 'take_so_nsubj', 'wonder_s_nsubj', 'use_so_nsubj', 'rememb_s_nsubj']
# Nouns:
# ['i', 'we', 'he', 'one', 'who', 'you', 'people', 'nobody', 'no', 'DIGIT', 'no-one', "'s", 'many', 'she', 'everyone', 'some', 'all', 'none', 'and', 'day']
#
#
#
# Class: 36
# Verbs:
# ['make_os_csubj', 'accus_so_dobj', 'demand_so_nsubj', 'adopt_so_nsubj', 'live_ss_nsubj', 'celebr_so_nsubj', 'attend_so_nsubj', 'hold_sso_nsubj', 'give_os_csubj', 'receiv_soo_nsubj', 'give_oos_csubj', 'flew_so_nsubj', 'face_sso_nsubj', 'concentr_s_nsubj', 'prefer_so_nsubj', 'discuss_sso_nsubj', 'owe_so_nsubj', 'benefit_s_nsubj', 'led_so_dobj', 'lead_so_dobj']
# Nouns:
# ['government', 'team', 'making', 'son', 'city', 'make', 'king', 'parliament', 'authorities', 'give', 'giving', 'ministers', 'west', 'did', 'engineers', 'racing', 'females', 'males', 'mps', 'fans']
#
#
#
# Class: 37
# Verbs:
# ['held_so_dobj', 'look_so_dobj', 'hold_so_dobj', 'kept_so_dobj', 'attend_so_dobj', 'sound_so_dobj', 'hold_o_dobj', 'look_o_dobj', 'organis_so_dobj', 'keep_so_dobj', 'lead_so_dobj', 'took_soo_dobj', 'pleas_o_dobj', 'keep_o_dobj', 'stage_so_dobj', 'gather_so_dobj', 'attend_o_dobj', 'put_soo_dobj', 'host_so_dobj', 'pleas_so_dobj']
# Nouns:
# ['meeting', 'note', 'show', 'think', 'best', 'pace', 'breath', 'meetings', 'conference', 'contact', 'friends', 'more', 'round', 'own', 'exhibition', 'step', 'position', 'players', 'watch', 'sort']
#
#
#
# Class: 38
# Verbs:
# ['enabl_so_dobj', 'face_o_dobj', 'allow_so_dobj', 'approach_so_dobj', 'enabl_o_dobj', 'blame_so_dobj', 'drive_so_dobj', 'prefer_so_dobj', 'help_so_dobj', 'use_so_nsubj', 'face_so_nsubj', 'recognis_so_nsubj', 'give_sooo_iobj', 'urg_so_dobj', 'want_so_dobj', 'give_soo_iobj', 'play_s_csubj', 'support_so_dobj', 'defi_so_dobj', 'find_so_nsubj']
# Nouns:
# ['company', 'those', 'government', 'industry', 'users', 'church', 'playing', 'union', 'play', 'authorities', 'groups', 'men', 'one', 'person', 'readers', 'reader', 'employers', 'institutions', 'state', 'britain']
#
#
#
# Class: 39
# Verbs:
# ['own_so_dobj', 'die_so_dobj', 'move_ss_nsubj', 'cost_soo_dobj', 'hear_soo_dobj', 'recognis_so_dobj', 'die_o_dobj', 'scream_so_dobj', 'name_o_dobj', 'fit_soo_dobj', 'star_ooo_dobj', 'hand_s_nsubj', 'yield_o_dobj', 'contain_ooo_dobj', 'averag_so_dobj', 'induc_so_dobj', 'pass_soo_dobj', 'wander_o_dobj', 'jump_o_dobj', 'pass_sso_nsubj']
# Nouns:
# ['death', 'm', 'camera', 'poor', 'victim', 'risks', 'pilots', 'seed', 'pick', 'block', 'beating', 'brushes', 'copyright', 'throne', 'charlton', 'planes', 'irish', 'queue', 'property', 'pets']
#
#
#
# Class: 40
# Verbs:
# ['won_so_dobj', 'lost_so_dobj', 'win_so_dobj', 'lose_so_dobj', 'win_o_dobj', 'keep_so_dobj', 'won_soo_dobj', 'break_so_dobj', 'take_oo_dobj', 'chose_so_dobj', 'sent_so_dobj', 'finish_so_dobj', 'gain_so_dobj', 'go_s_nsubj', 'went_s_nsubj', 'lose_o_dobj', 'want_so_dobj', 'defend_so_dobj', 'win_soo_dobj', 'win_s_nsubj']
# Nouns:
# ['two', 'title', 'DIGIT', 'cup', 'law', 'prize', 'race', 'three', 'award', 'rest', 'championship', 'match', 'one', 'four', 'election', 'seats', 'ground', 'ball', 'control', 'gold']
#
#
#
# Class: 41
# Verbs:
# ['wa_s_nsubj', 'came_s_nsubj', 'caus_so_nsubj', 'wa_ss_nsubj', "'s_s_nsubj", 'saw_so_dobj', 'see_so_dobj', 'prevent_so_nsubj', 'last_s_nsubj', 'led_s_nsubj', 'flow_s_nsubj', 'prove_so_nsubj', 'occur_s_nsubj', 'rememb_so_dobj', 'took_so_nsubj', 'produc_so_nsubj', 'exist_s_nsubj', 'affect_so_nsubj', 'erupt_s_nsubj', 'aros_s_nsubj']
# Nouns:
# ['it', 'that', 'this', 'silence', 'time', 'one', 'sign', 'reason', 'need', 'evidence', 'way', 'question', 'blood', 'war', 'change', 'point', 'light', 'pause', 'feeling', 'moment']
#
#
#
# Class: 42
# Verbs:
# ['offer_so_nsubj', 'stand_s_nsubj', 'present_so_nsubj', 'develop_so_nsubj', 'offer_soo_nsubj', 'introduc_so_nsubj', 'serv_s_nsubj', 'retain_so_nsubj', 'oper_s_nsubj', 'reveal_so_nsubj', 'report_so_nsubj', 'achiev_so_nsubj', 'produc_so_nsubj', 'reli_s_nsubj', 'lead_so_nsubj', 'display_so_nsubj', 'employ_so_nsubj', 'set_s_nsubj', 'record_so_nsubj', 'share_so_nsubj']
# Nouns:
# ['which', 'it', 'he', 'they', 'who', 'we', 'that', 'company', 'she', 'government', 'i', 'DIGIT', 'group', 'this', 'some', 'companies', 'hotel', 'one', 'most', 'gallery']
#
#
#
# Class: 43
# Verbs:
# ['take_sso_nsubj', 'bring_so_nsubj', 'suggest_so_nsubj', 'reduc_so_nsubj', 'add_so_nsubj', 'identifi_so_nsubj', 'remov_so_nsubj', 'send_so_nsubj', 'improv_so_nsubj', 'draw_s_nsubj', 'predict_so_nsubj', 'avoid_so_nsubj', 'add_s_nsubj', 'deal_s_nsubj', 'continu_ss_nsubj', 'feed_so_nsubj', 'blend_s_nsubj', 'watch_os_csubj', 'transform_so_nsubj', 'miss_soo_dobj']
# Nouns:
# ['watching', 'john', 'drawing', 'responses', 'cats', 'analysts', 'distribution', 'fall', 'killing', 'loan', 'judging', 'all', 'mist', 'slide', 'fleet', 'called', 'action', 'gathering', 'marshall', 'study']
#
#
#
# Class: 44
# Verbs:
# ['look_s_nsubj', 'ask_s_nsubj', 'wa_s_nsubj', 'felt_s_nsubj', 'saw_so_nsubj', 'ask_so_nsubj', 'look_so_nsubj', 'say_s_nsubj', 'made_so_nsubj', 'felt_so_nsubj', 'move_s_nsubj', 'see_so_nsubj', 'turn_s_nsubj', 'knew_s_nsubj', 'go_s_nsubj', 'found_so_nsubj', 'left_so_nsubj', 'met_so_nsubj', 'take_so_nsubj', 'walk_s_nsubj']
# Nouns:
# ['he', 'she', 'i', 'they', 'who', 'we', 'people', 'some', 'men', 'jack', 'boy', 'charles', 'it', 'mungo', 'cameron', 'constance', 'maggie', 'john', 'mother', 'diana']
#
#
#
# Class: 45
# Verbs:
# ['miss_so_dobj', 'stand_so_dobj', 'stood_so_dobj', 'round_so_nsubj', 'seiz_so_dobj', 'sang_so_dobj', 'crash_s_nsubj', 'sing_so_dobj', 'offer_s_nsubj', 'miss_o_dobj', 'pay_s_nsubj', 'name_so_dobj', 'join_sso_nsubj', 'came_s_nsubj', 'last_so_nsubj', 'equalis_s_nsubj', 'play_ss_nsubj', 'resent_so_dobj', 'keep_sooooo_dobj', 'run_soo_nsubj']
# Nouns:
# ['chance', 'opportunity', 'song', 'songs', 'it', 'all', 'experiences', 'guard', 'shops', 'point', 'firm', 'green', 'reason', 'rewards', 'there', 'f', 'mud', 'bush', 'putt', 'tories']
#
#
#
# Class: 46
# Verbs:
# ['affect_so_dobj', 'reflect_so_dobj', 'consid_so_dobj', 'depend_s_nsubj', 'encourag_so_dobj', 'maintain_so_dobj', 'discuss_so_dobj', 'stress_so_dobj', 'promot_so_dobj', 'develop_so_dobj', 'deni_so_dobj', 'suggest_so_dobj', 'confirm_so_dobj', 'establish_so_dobj', 'influenc_so_dobj', 'indic_so_dobj', 'involv_so_dobj', 'support_so_dobj', 'illustr_so_dobj', 'determin_so_dobj']
# Nouns:
# ['importance', 'development', 'relationship', 'behaviour', 'view', 'use', 'ideas', 'position', 'aspects', 'need', 'areas', 'plans', 'history', 'existence', 'everything', 'performance', 'role', 'relations', 'nature', 'relationships']
#
#
#
# Class: 47
# Verbs:
# ['carri_so_nsubj', 'grow_s_nsubj', 'lay_s_nsubj', 'form_so_nsubj', 'began_s_nsubj', 'develop_s_nsubj', 'surviv_s_nsubj', 'end_s_nsubj', 'replac_so_nsubj', 'ran_s_nsubj', 'attract_so_nsubj', 'sign_so_dobj', 'domin_so_nsubj', 'featur_soo_dobj', 'goe_so_nsubj', 'threaten_so_nsubj', 'lend_so_nsubj', 'make_soo_nsubj', 'see_ooo_dobj', 'live_s_csubj']
# Nouns:
# ['war', 'living', 'contract', 'year', 'press', 'ships', 'increasing', 'structures', 'plant', 'newspapers', 'plants', 'live', 'interest', 'many', 'measuring', 'DIGIT', 'bones', 'idea', 'treaty', 'deal']
#
#
#
# Class: 48
# Verbs:
# ['offer_so_dobj', 'provid_so_dobj', 'requir_so_dobj', 'provid_soo_dobj', 'provid_o_dobj', 'offer_soo_dobj', 'offer_o_dobj', 'requir_soo_dobj', 'provid_sooo_dobj', 'share_so_dobj', 'improv_so_dobj', 'requir_o_dobj', 'bring_so_dobj', 'offer_sooo_dobj', 'afford_so_dobj', 'involv_o_dobj', 'improv_o_dobj', 'includ_so_dobj', 'doe_os_csubj', 'offer_sso_dobj']
# Nouns:
# ['services', 'range', 'skills', 'service', 'facilities', 'support', 'opportunities', 'does', 'access', 'resources', 'rights', 'accommodation', 'conditions', 'care', 'views', 'choice', 'knowledge', 'experience', 'variety', 'protection']
#
#
#
# Class: 49
# Verbs:
# ['get_so_dobj', 'heard_so_dobj', 'want_so_dobj', 'hear_so_dobj', 'mean_so_dobj', 'eat_so_dobj', "'s_ss_nsubj", 'eat_o_dobj', 'commit_so_dobj', 'came_o_dobj', 'keep_os_csubj', 'ate_so_dobj', 'attack_so_dobj', 'hear_o_dobj', 'like_so_dobj', 'make_oo_dobj', 'featur_sooo_dobj', 'remov_o_dobj', 'feed_so_dobj', 'suppos_os_csubj']
# Nouns:
# ['voice', 'do', 'sound', 'keeping', 'sounds', 'noise', 'voices', 'anything', 'food', 'keep', 'meal', 'suicide', 'bits', 'bread', 'meals', 'one', 'fish', 'supposing', 'suppose', 'add']
#
#
#
# Class: 50
# Verbs:
# ['ha_soo_nsubj', 'hit_so_nsubj', 'deliv_so_nsubj', 'let_os_csubj', 'confirm_so_nsubj', 'drove_so_nsubj', 'cut_s_nsubj', 'manag_so_nsubj', 'stress_so_nsubj', 'match_so_nsubj', 'cross_s_nsubj', 'own_so_nsubj', 'pursu_so_nsubj', 'won_soo_nsubj', 'make_so_csubj', 'wait_s_csubj', 'ha_ssso_nsubj', 'let_s_nsubj', 'specialis_s_nsubj', 'share_os_csubj']
# Nouns:
# ['let', 'france', 'bank', 'sharing', 'wait', 'roads', 'brain', 'letting', 'guitars', 'mill', 'bull', 'walker', 'rivals', 'programmer', 'waiting', 'stores', 'poverty', 'onions', 'greed', 'tower']
#
#
#
# Class: 51
# Verbs:
# ['cut_so_dobj', 'cut_o_dobj', 'paid_so_dobj', 'remov_oo_dobj', 'leav_os_csubj', 'paint_so_dobj', 'brush_so_dobj', 'fight_o_dobj', 'peg_s_nsubj', 'bit_so_dobj', 'tore_so_dobj', 'compris_oooo_dobj', 'blew_so_dobj', 'leav_s_csubj', 'blow_so_dobj', 'stamp_so_dobj', 'tie_so_dobj', 'tie_o_dobj', 'fix_o_dobj', 'remov_o_dobj']
# Nouns:
# ['feet', 'leaves', 'smoke', 'hair', 'leaving', 'dust', 'lip', 'memory', 'streets', 'fighting', 'leave', 'branches', 'boards', 'visit', 'teeth', 'grass', 'ice', 'toes', 'brush', 'caring']
#
#
#
# Class: 52
# Verbs:
# ['say_s_nsubj', 'say_so_nsubj', 'tell_so_nsubj', 'enter_so_nsubj', 'marri_so_dobj', 'use_sso_nsubj', 'read_so_nsubj', 'put_s_nsubj', 'play_sso_nsubj', 'return_so_nsubj', 'marri_so_nsubj', 'plan_so_nsubj', 'recal_s_nsubj', 'got_sso_nsubj', 'follow_os_csubj', 'said_os_nsubj', 'pick_so_nsubj', 'say_o_dobj', 'knock_s_nsubj', 'assum_os_csubj']
# Nouns:
# ['wife', 'daughter', 'one', 'someone', 'following', 'wilson', 'teacher', 'person', 'people', 'doctors', 'assuming', 'christ', 'jane', 'he', 'follow', 'anderson', 'returning', 'earl', 'some', 'understand']
#
#
#
# Class: 53
# Verbs:
# ['show_soo_dobj', 'includ_soooooooo_dobj', 'thank_o_dobj', 'ha_so_csubj', 'includ_soooooooooo_dobj', 'link_oo_dobj', 'look_sss_nsubj', 'relax_o_dobj', 'handl_soo_dobj', 'includ_sooooooo_dobj', 'bless_so_nsubj', 'said_oss_csubj', 'help_so_nsubj', 'reject_soo_dobj', 'brave_so_dobj', 'gave_ssoo_nsubj', 'cover_sooooo_dobj', 'cut_os_csubj', 'compris_soooo_dobj', 'allow_soo_dobj']
# Nouns:
# ['god', 'heart', 'air', 'corp', 'muscles', 'said', 'cutting', 'wood', 'violence', 'inc', 'object', 'windows', 'elements', 'sue', 'fields', 'climbing', 'sheep', 'switch', 'ltd', 'rocks']
#
#
#
# Class: 54
# Verbs:
# ['find_so_dobj', 'accept_so_dobj', 'prove_so_dobj', 'find_o_dobj', 'live_so_dobj', 'reject_so_dobj', 'came_s_nsubj', 'lie_s_nsubj', 'save_so_dobj', 'refus_so_dobj', 'like_so_dobj', 'accept_o_dobj', 'enjoy_so_dobj', "'ve_so_dobj", 'found_so_dobj', 'live_o_dobj', 'see_so_dobj', 'got_so_dobj', 'lead_so_dobj', 'domin_so_dobj']
# Nouns:
# ['life', 'idea', 'lives', 'point', 'offer', 'balance', 'expression', 'answer', 'challenge', 'space', 'there', 'job', 'sex', 'invitation', 'one', 'work', 'ways', 'way', 'success', 'responsibility']
#
#
#
# Class: 55
# Verbs:
# ['ha_so_nsubj', 'provid_so_nsubj', 'includ_so_nsubj', 'lead_s_nsubj', 'caus_so_nsubj', 'led_s_nsubj', 'take_so_nsubj', 'occur_s_nsubj', 'make_so_nsubj', 'give_so_nsubj', 'result_s_nsubj', 'affect_so_nsubj', 'give_soo_nsubj', 'come_s_nsubj', 'contain_so_nsubj', 'form_so_nsubj', 'involv_so_nsubj', 'appear_s_nsubj', 'produc_so_nsubj', 'exist_s_nsubj']
# Nouns:
# ['which', 'that', 'they', 'this', 'these', 'it', 'putting', '’', 'many', 'type', 'both', 'factors', 'first', 'structure', 'state', 'none', 'latter', 'drugs', 'effects', 'law']
#
#
#
# Class: 56
# Verbs:
# ['fail_s_nsubj', 'nod_so_dobj', 'shook_so_dobj', 'forget_o_dobj', 'shrug_so_dobj', 'wipe_so_dobj', 'come_s_csubj', 'call_sso_nsubj', 'lift_oo_dobj', 'poke_so_dobj', 'rais_oo_dobj', 'condemn_o_dobj', 'pour_s_nsubj', 'rais_ooo_dobj', 'call_os_nsubj', 'trickl_s_nsubj', 'led_sso_nsubj', 'demonstr_s_nsubj', 'berth_so_dobj', 'conclud_so_nsubj']
# Nouns:
# ['head', 'shoulders', 'agreement', 'rain', 'coming', 'sweat', 'attempts', 'tears', 'words', 'remains', 'fun', 'breasts', 'hills', 'attempt', 'forehead', 'blood', 'pies', 'horizons', 'brow', 'customs']
#
#
#
# Class: 57
# Verbs:
# ['said_s_nsubj', 'took_so_nsubj', 'look_s_nsubj', 'smile_s_nsubj', 'ask_s_nsubj', 'nod_s_nsubj', 'put_so_nsubj', 'turn_s_nsubj', 'thought_s_nsubj', 'said_ss_nsubj', 'shook_so_nsubj', 'stare_s_nsubj', 'told_so_nsubj', 'open_so_nsubj', 'push_so_nsubj', 'glanc_s_nsubj', 'paus_s_nsubj', 'gave_so_nsubj', 'walk_s_nsubj', 'rais_so_nsubj']
# Nouns:
# ['he', 'she', 'i', 'they', 'man', 'corbett', 'nordern', 'who', 'maggie', 'delaney', 'yanto', 'one', 'peter', 'woman', 'kelly', 'emily', 'philip', 'joe', 'tom', 'bragg']
#
#
#
# Class: 58
# Verbs:
# ['rose_so_dobj', 'fell_so_dobj', 'cost_so_dobj', 'reach_so_dobj', 'weigh_so_dobj', 'jump_so_dobj', 'exceed_so_dobj', 'grew_so_dobj', 'ha_so_dobj', 'reach_o_dobj', 'cost_soo_dobj', 'weigh_o_dobj', 'grow_so_dobj', 'fall_so_dobj', 'contribut_so_dobj', 'lost_so_dobj', 'pay_so_dobj', 'cost_o_dobj', 'receiv_so_dobj', 'est._o_dobj']
# Nouns:
# ['DIGIT', '%', 'end', 'points', 'much', 'teeth', 'million', 'm', 'light', '$', 'please', 'lying', 'victim', 'short', 'pounds', 'feet', 'foul', 'stone', 'more', 'tons']
#
#
#
# Class: 59
# Verbs:
# ['left_so_dobj', 'enter_so_dobj', 'reach_so_dobj', 'see_so_dobj', 'cross_so_dobj', 'leav_so_dobj', 'visit_so_dobj', 'set_so_dobj', 'leav_o_dobj', 'cover_so_dobj', 'enter_o_dobj', 'hit_so_dobj', 'occupi_so_dobj', 'built_so_dobj', 'cross_o_dobj', 'overlook_o_dobj', 'ha_soo_dobj', 'fill_so_dobj', 'visit_o_dobj', 'domin_so_dobj']
# Nouns:
# ['room', 'house', 'school', 'area', 'ground', 'road', 'world', 'home', 'land', 'garden', 'walls', 'office', 'scene', 'field', 'bridge', 'face', 'church', 'stage', 'site', 'street']
#
#
#
# Class: 60
# Verbs:
# ['happen_s_nsubj', 'say_os_dobj', 'mean_os_dobj', 'think_os_dobj', 'want_os_dobj', 'wa_os_dobj', 'happen_ss_nsubj', 'goe_s_nsubj', 'doe_so_nsubj', 'know_os_dobj', 'said_os_dobj', 'call_oso_dobj', 'go_s_nsubj', 'see_os_dobj', 'say_oss_dobj', 'want_oss_dobj', 'like_os_dobj', 'follow_ss_nsubj', 'know_so_dobj', 'talk_os_dobj']
# Nouns:
# ['what', 'whatever', 'whom', 'that', 'which', 'follows', '‘', 'same', 'sort', 'hell', 'this', 'all', 'whoever', 'things', 'accident', 'kind', 'who', 'washing', 'accidents', 'it']
#
#
#
# Class: 61
# Verbs:
# ['felt_so_dobj', 'grew_s_nsubj', 'increas_s_nsubj', 'increas_so_nsubj', 'fill_so_dobj', 'appeal_s_nsubj', 'report_so_dobj', 'suggest_o_dobj', 'caus_so_nsubj', 'exceed_so_nsubj', 'grew_so_nsubj', 'enhanc_so_nsubj', 'caus_soo_nsubj', 'fill_o_dobj', 'grow_s_nsubj', 'induc_so_nsubj', 'occur_so_dobj', 'evolv_s_nsubj', 'mind_so_dobj', 'boost_so_nsubj']
# Nouns:
# ['sales', 'population', 'gap', 'lack', 'blow', 'figures', 'number', 'demand', 'increase', 'smoking', 'prospect', 'wave', 'anxiety', 'output', 'consequences', 'air', 'weather', 'event', 'gaps', 'revenues']
#
#
#
# Class: 62
# Verbs:
# ['receiv_so_nsubj', 'make_so_nsubj', 'sell_so_nsubj', 'travel_s_nsubj', 'respond_s_nsubj', 'come_so_nsubj', 'help_s_nsubj', 'work_s_nsubj', 'get_so_nsubj', 'regard_so_nsubj', 'insist_s_nsubj', 'defin_so_nsubj', 'decid_s_nsubj', 'join_s_nsubj', 'deserv_so_nsubj', 'treat_so_nsubj', 'emphasis_so_nsubj', 'lose_so_nsubj', 'charg_s_nsubj', 'fight_s_nsubj']
# Nouns:
# ['he', 'they', 'it', 'who', 'we', 'both', 'employees', 'farmers', 'people', 'managers', 'goldberg', 'she', 'shareholders', 'beach', 'members', 'computer', 'those', 'you', 'company', 'workers']
#
#
#
# Class: 63
# Verbs:
# ['go_s_nsubj', 'look_s_nsubj', 'live_s_nsubj', 'take_so_nsubj', 'get_so_nsubj', 'come_s_nsubj', 'talk_s_nsubj', 'use_so_nsubj', 'see_so_nsubj', 'get_s_nsubj', 'make_so_nsubj', 'reach_so_nsubj', 'find_so_nsubj', 'got_so_nsubj', 'work_s_nsubj', 'know_s_nsubj', 'want_so_nsubj', 'move_s_nsubj', 'found_so_nsubj', 'want_s_nsubj']
# Nouns:
# ['they', 'we', 'you', 'it', 'i', 'he', 'who', 'DIGIT', 'companies', 'group', 'this', 'that', 'government', 'two', 'to', 'police', 'shall', 'all', 'groups', 'some']
#
#
#
# Class: 64
# Verbs:
# ['saw_so_dobj', 'follow_so_dobj', 'hit_so_dobj', 'led_so_dobj', 'see_so_dobj', 'ask_so_dobj', 'watch_so_dobj', 'struck_so_dobj', 'knew_so_dobj', 'stop_so_dobj', 'took_so_dobj', 'met_so_dobj', 'kiss_so_dobj', 'follow_o_dobj', 'love_so_dobj', 'gave_soo_iobj', 'told_so_dobj', 'like_so_dobj', 'left_so_dobj', 'know_so_dobj']
# Nouns:
# ['him', 'her', 'me', 'other', 'them', 'side', 'man', 'one', 'ball', 'path', 'girl', 'shot', 'men', 'instructions', 'travelling', 'suit', 'upwards', 'face', 'headlines', 'car']
#
#
#
# Class: 65
# Verbs:
# ['wait_s_nsubj', 'repli_s_nsubj', 'close_so_nsubj', 'greet_so_nsubj', 'accompani_so_nsubj', 'demand_s_nsubj', 'press_so_nsubj', 'thank_oo_dobj', 'announc_s_nsubj', 'recogn_so_nsubj', 'star_s_nsubj', 'whistl_s_nsubj', 'kick_s_nsubj', 'bow_s_nsubj', 'fetch_so_nsubj', 'heard_s_nsubj', 'tap_so_nsubj', 'swept_so_nsubj', 'stroll_s_nsubj', 'know_sso_nsubj']
# Nouns:
# ['america', 'whoever', 'sir', 'mark', '•', 'public', 'driver', 'thomas', 'butler', 'johnson', 'o', 'richard', 'customers', 'vi', 'nigel', 'free', 'williams', 'trent', 'frank', 'flora']
#
#
#
# Class: 66
# Verbs:
# ['includ_so_dobj', 'show_so_nsubj', 'contain_so_dobj', 'produc_so_nsubj', 'includ_so_nsubj', 'includ_sooo_dobj', 'emerg_s_nsubj', 'includ_soo_dobj', 'act_s_nsubj', 'compris_so_dobj', 'show_s_nsubj', 'reveal_so_nsubj', 'illustr_so_nsubj', 'contain_soo_dobj', 'featur_so_dobj', 'contain_o_dobj', 'includ_soo_nsubj', 'show_soo_nsubj', 'present_so_dobj', 'rang_s_nsubj']
# Nouns:
# ['works', 'number', 'figure', 'picture', 'figures', 'list', 'work', 'examples', 'items', 'table', 'information', 'collection', 'pictures', 'selection', 'DIGIT', 'some', 'plan', 'one', 'photographs', 'analysis']
#
#
#
# Class: 67
# Verbs:
# ['take_so_dobj', 'took_so_dobj', 'take_o_dobj', 'take_soo_dobj', 'take_sso_dobj', 'take_os_dobj', 'took_sso_dobj', 'ha_so_dobj', 'took_soo_dobj', 'take_oo_dobj', 'found_so_dobj', 'took_o_dobj', 'find_so_dobj', 'gave_soo_dobj', 'share_so_dobj', 'take_oso_dobj', 'occupi_so_dobj', 'hold_so_dobj', 'give_soo_dobj', 'want_so_dobj']
# Nouns:
# ['place', 'it', 'part', 'time', 'care', 'form', 'advantage', 'them', 'look', 'action', 'me', 'account', 'him', 'us', 'notice', 'hold', 'lead', 'steps', 'view', 'step']
#
#
#
# Class: 68
# Verbs:
# ['get_so_nsubj', 'find_so_nsubj', 'know_s_nsubj', 'see_so_nsubj', 'get_s_nsubj', 'give_soo_iobj', 'go_s_nsubj', 'know_so_nsubj', 'see_s_nsubj', 'thank_o_dobj', 'take_so_nsubj', 'make_so_nsubj', 'think_s_nsubj', 'look_s_nsubj', 'use_so_nsubj', 'tell_so_dobj', 'want_so_nsubj', 'buy_so_nsubj', 'want_s_nsubj', 'come_s_nsubj']
# Nouns:
# ['you', 'anyone', 'people', 'one', 'god', 'ye', 'everyone', 'all', 'person', 'lord', 'someone', 'those', 'man', 'customers', 'anybody', 'goodness', 'woman', 'readers', 'nobody', 'some']
#
#
#
# Class: 69
# Verbs:
# ['pay_so_dobj', 'serv_so_dobj', 'includ_soooooo_dobj', 'cover_so_dobj', 'place_so_dobj', 'lay_so_dobj', 'paid_so_dobj', 'includ_sooo_nsubj', 'produc_soo_dobj', 'impos_so_dobj', 'serv_o_dobj', 'pay_o_dobj', 'repres_o_dobj', 'pay_soo_dobj', 'hold_o_dobj', 'charg_so_dobj', 'laid_so_dobj', 'drank_so_dobj', 'drink_so_dobj', 'pour_so_dobj']
# Nouns:
# ['price', 'costs', 'cost', 'eggs', 'coffee', 'interests', 'tea', 'emphasis', 'tax', 'fee', 'purpose', 'wine', 'fees', 'miles', 'drink', 'house', 'beer', 'interest', 'glass', 'DIGIT']
#
#
#
# Class: 70
# Verbs:
# ['take_so_nsubj', 'occur_s_nsubj', 'took_so_nsubj', 'work_ss_nsubj', 'explain_so_nsubj', 'extend_so_nsubj', 'occur_ss_nsubj', 'admit_so_dobj', 'rais_so_nsubj', 'prevent_so_dobj', 'saw_sso_nsubj', 'came_s_nsubj', 'found_sso_nsubj', 'attribut_so_nsubj', 'recal_so_dobj', 'occur_so_nsubj', 'belong_ss_nsubj', 'wit_so_dobj', 'involv_so_nsubj', 'describ_so_dobj']
# Nouns:
# ['some', 'events', 'changes', 'groups', 'societies', 'incident', 'event', 'dogs', 'example', 'one', 'cases', 'passage', 'most', 'accidents', 'owners', 'research', 'change', 'administration', 'developments', 'reactions']
#
#
#
# Class: 71
# Verbs:
# ['put_so_nsubj', 'arriv_s_nsubj', 'won_so_nsubj', 'lost_so_nsubj', 'took_so_nsubj', 'turn_so_nsubj', 'stood_s_nsubj', 'kept_so_nsubj', 'suffer_so_nsubj', 'speak_s_nsubj', 'saw_so_nsubj', 'broke_so_nsubj', 'approach_so_nsubj', 'appear_s_nsubj', 'made_soo_nsubj', 'publish_so_nsubj', 'broke_s_nsubj', 'enter_s_nsubj', 'brought_so_nsubj', 'conduct_so_nsubj']
# Nouns:
# ['he', 'who', 'they', 'she', 'we', 'i', 'which', 'that', 'labour', 'it', 'one', 'men', 'man', 'group', 'government', 'party', 'DIGIT', 'team', 'company', 'police']
#
#
#
# Class: 72
# Verbs:
# ['told_so_dobj', 'tell_so_dobj', 'tell_o_dobj', 'tell_soo_dobj', 'includ_sooooooooo_dobj', 'told_s_nsubj', 'told_soo_dobj', 'address_so_dobj', 'direct_so_dobj', 'tell_oo_dobj', 'upheld_so_nsubj', 'reject_so_nsubj', 'took_so_nsubj', 'open_sso_nsubj', 'heard_s_nsubj', 'summon_so_dobj', 'heard_so_nsubj', 'rememb_so_dobj', 'look_oo_dobj', 'beat_oo_dobj']
# Nouns:
# ['story', 'court', 'conference', 'truth', 'stories', 'audience', 'all', 'jury', 'tale', 'judge', 'newspaper', 'tales', 'house', 'friends', 'press', 'meeting', 'lies', 'committee', 'police', 'tribunal']
#
#
#
# Class: 73
# Verbs:
# ['go_s_nsubj', 'kill_so_dobj', 'leav_so_nsubj', 'employ_so_dobj', 'learn_s_nsubj', 'die_s_nsubj', 'spend_so_nsubj', 'use_so_nsubj', 'help_so_dobj', 'take_so_nsubj', 'find_s_nsubj', 'behav_s_nsubj', 'find_so_nsubj', 'suffer_s_nsubj', 'feel_s_nsubj', 'talk_s_nsubj', 'affect_so_dobj', 'want_so_dobj', 'experi_so_nsubj', 'attract_so_dobj']
# Nouns:
# ['people', 'children', 'women', 'others', 'men', 'child', 'students', 'parents', 'those', 'staff', 'patient', 'pupils', 'person', 'some', 'workers', 'patients', 'thousands', 'someone', 'girls', 'media']
#
#
#
# Class: 74
# Verbs:
# ['play_so_dobj', 'play_o_dobj', 'perform_so_dobj', 'use_os_csubj', 'play_soo_dobj', 'get_o_dobj', 'play_sso_dobj', 'perform_o_dobj', 'contain_oo_dobj', 'read_os_csubj', 'play_os_dobj', 'play_oo_dobj', 'form_soo_dobj', 'retain_so_dobj', 'read_s_csubj', 'invent_so_dobj', 'defend_so_dobj', 'fulfil_so_dobj', 'repeat_o_dobj', 'consid_o_dobj']
# Nouns:
# ['part', 'role', 'using', 'game', 'reading', 'music', 'games', 'training', 'football', 'guitar', 'roles', 'ones', 'functions', 'position', 'host', 'tennis', 'had', 'cards', 'order', 'bit']
#
#
#
# Class: 75
# Verbs:
# ['make_so_dobj', 'made_so_dobj', 'make_o_dobj', 'make_soo_dobj', 'creat_so_dobj', 'present_so_dobj', 'make_sso_dobj', 'make_os_dobj', 'suffer_so_dobj', 'made_soo_dobj', 'avoid_so_dobj', 'came_s_nsubj', 'made_sso_dobj', 'see_so_dobj', 'repres_so_dobj', 'involv_so_dobj', 'made_o_dobj', 'saw_so_dobj', 'lie_s_nsubj', 'mark_so_dobj']
# Nouns:
# ['sense', 'use', 'difference', 'it', 'way', 'attempt', 'effort', 'contribution', 'debut', 'love', 'point', 'progress', 'mistake', 'appearance', 'decision', 'problems', 'decisions', 'demands', 'move', 'most']
#
#
#
# Class: 76
# Verbs:
# ['go_so_dobj', 'went_so_dobj', 'came_so_dobj', 'come_so_dobj', 'caught_so_dobj', 'work_so_dobj', 'got_so_dobj', 'goe_so_dobj', 'go_o_dobj', 'come_o_dobj', 'get_so_dobj', 'look_so_dobj', 'catch_so_dobj', 'walk_so_dobj', 'find_so_dobj', 'keep_o_dobj', 'return_so_dobj', 'gave_so_dobj', 'stay_so_dobj', 'arriv_so_dobj']
# Nouns:
# ['way', 'home', 'round', 'eye', 'better', 'there', 'say', 'distance', 'all', 'miles', 'one', 'saying', 'sight', 'time', 'ways', 'further', 'hand', 'shopping', 'past', 'bit']
#
#
#
# Class: 77
# Verbs:
# ['put_so_dobj', 'carri_so_dobj', 'carri_o_dobj', 'put_o_dobj', 'got_so_dobj', 'broke_so_dobj', 'remov_so_dobj', 'hold_o_dobj', 'grab_so_dobj', 'place_so_dobj', 'lit_so_dobj', 'pull_so_dobj', 'drop_so_dobj', 'threw_so_dobj', 'saw_so_dobj', 'push_so_dobj', 'throw_so_dobj', 'keep_o_dobj', 'gave_sooo_dobj', 'mark_so_dobj']
# Nouns:
# ['them', 'arms', 'bag', 'arm', 'leg', 'weight', 'car', 'pressure', 'it', 'fire', 'one', 'piece', 'light', 'lights', 'money', 'little', 'end', 'ball', 'gun', 'cigarette']
#
#
#
# Class: 78
# Verbs:
# ['shook_so_dobj', 'put_so_dobj', 'lift_so_dobj', 'rais_so_dobj', 'turn_so_dobj', 'drop_so_dobj', 'touch_so_dobj', 'met_so_dobj', 'rub_so_dobj', 'wave_so_dobj', 'press_so_dobj', 'hold_o_dobj', 'held_so_dobj', 'turn_o_dobj', 'shake_so_dobj', 'keep_o_dobj', 'pull_so_dobj', 'place_o_dobj', 'put_o_dobj', 'keep_so_dobj']
# Nouns:
# ['head', 'hand', 'hands', 'face', 'eyes', 'them', 'fingers', 'body', 'finger', 'heads', 'foot', 'arm', 'it', 'feet', 'hair', 'lips', 'arms', 'back', 'neck', 'shoulder']
#
#
#
# Class: 79
# Verbs:
# ['read_so_dobj', 'wrote_so_dobj', 'write_so_dobj', 'publish_so_dobj', 'read_o_dobj', 'write_o_dobj', 'contain_so_nsubj', 'produc_so_dobj', 'provid_so_nsubj', 'appear_s_nsubj', 'ha_sso_nsubj', 'issu_so_dobj', 'receiv_so_dobj', 'deliv_so_dobj', 'walk_so_nsubj', 'give_so_nsubj', 'prepar_so_dobj', 'present_so_dobj', 'wrote_soo_dobj', 'read_soo_dobj']
# Nouns:
# ['the', 'book', 'report', 'a', 'letter', 'books', 'paper', 'letters', 'article', 'reports', 'lines', 'activities', 'papers', 'text', 'accounts', 'studies', 'document', 'account', 'day', 'list']
#
#
#
# Class: 80
# Verbs:
# ['ha_so_dobj', 'ha_soo_dobj', 'lie_s_nsubj', 'retain_so_dobj', 'give_soo_dobj', 'lack_so_dobj', 'lose_so_dobj', 'increas_so_dobj', 'achiev_so_dobj', 'ha_o_dobj', 'possess_so_dobj', 'carri_so_dobj', 'acquir_so_dobj', 'ha_sooo_dobj', 'ha_sso_dobj', 'add_so_dobj', 'depend_s_nsubj', 'see_so_dobj', 'exercis_so_dobj', 'gain_so_dobj']
# Nouns:
# ['power', 'right', 'effect', 'value', 'responsibility', 'interest', 'potential', 'influence', 'advantage', 'reputation', 'implications', 'experience', 'sense', 'advantages', 'number', 'ability', 'control', 'capacity', 'one', 'authority']
#
#
#
# Class: 81
# Verbs:
# ['includ_so_nsubj', 'consist_s_nsubj', 'cover_so_nsubj', 'includ_soo_nsubj', 'requir_so_nsubj', 'includ_sooo_nsubj', 'creat_so_nsubj', 'includ_s_nsubj', 'featur_so_nsubj', 'contain_so_nsubj', 'call_oso_dobj', 'includ_soooo_nsubj', 'account_s_nsubj', 'reflect_so_nsubj', 'allow_so_nsubj', 'speak_so_dobj', 'contribut_s_nsubj', 'indic_so_nsubj', 'form_so_nsubj', 'provid_so_nsubj']
# Nouns:
# ['which', 'it', 'these', 'whom', 'they', 'this', 'act', 'english', 'exhibition', 'price', 'factors', 'language', 'programme', 'legislation', 'features', 'range', 'group', 'collection', 'law', 'schools']
#
#
#
# Class: 82
# Verbs:
# ['score_so_dobj', 'claim_so_dobj', 'attract_so_dobj', 'pull_so_dobj', 'issu_so_dobj', 'came_s_nsubj', 'got_soo_dobj', 'land_so_dobj', 'mean_o_dobj', 'serv_o_dobj', 'repres_soo_dobj', 'ha_os_csubj', 'score_o_dobj', 'miss_s_nsubj', 'ad_so_dobj', 'destroy_so_dobj', 'hit_so_dobj', 'conced_so_dobj', 'meet_o_dobj', 'compris_o_dobj']
# Nouns:
# ['goal', 'goals', 'try', 'hopes', 'another', 'has', 'birds', 'couple', 'first', 'cells', 'third', 'visitors', 'winner', 'six', 'five', 'runs', 'condition', 'hundreds', 'second', 'victory']
#
#
#
# Class: 83
# Verbs:
# ['see_so_nsubj', 'agre_s_nsubj', 'refer_s_nsubj', 'call_so_nsubj', 'start_so_nsubj', 'consid_so_nsubj', 'look_s_nsubj', 'welcom_so_nsubj', 'expect_so_nsubj', 'find_so_nsubj', 'got_s_nsubj', 'make_so_nsubj', 'note_so_nsubj', 'blame_so_nsubj', 'continu_so_nsubj', 'discuss_so_nsubj', 'come_ss_nsubj', 'feel_so_nsubj', 'explor_so_nsubj', 'ask_so_nsubj']
# Nouns:
# ['one', 'we', 'i', 'everyone', 'teachers', 'people', 'he', 'board', 'you', 'now', 'parents', 'some', 'company', 'all', 'committee', 'anyone', 'they', 'who', 'visitors', 'others']
#
#
#
# Class: 84
# Verbs:
# ['give_so_nsubj', 'came_ss_nsubj', 'set_so_nsubj', 'brought_so_nsubj', 'mean_so_nsubj', 'fill_so_nsubj', 'exist_s_nsubj', 'hung_s_nsubj', 'encourag_so_nsubj', 'draw_so_nsubj', 'thrive_s_nsubj', 'hang_s_nsubj', 'feed_s_nsubj', 'gener_so_nsubj', 'repres_sso_nsubj', 'demonstr_so_nsubj', 'said_sso_nsubj', 'reach_s_nsubj', 'reflect_s_nsubj', 'swept_s_nsubj']
# Nouns:
# ['fish', 'movement', 'beauty', 'knowledge', 'smell', 'waters', 'combination', 'stations', 'culture', 'scenes', 'businesses', 'underlying', 'division', 'DIGIT', 'product', 'unemployment', 'trap', 'bear', 'angels', 'posters']
#
#
#
# Class: 85
# Verbs:
# ['describ_so_nsubj', 'left_so_nsubj', 'turn_s_nsubj', 'complet_so_nsubj', 'address_so_nsubj', 'warn_so_nsubj', 'let_so_nsubj', 'saw_so_nsubj', 'stood_so_nsubj', 'hit_s_nsubj', 'outlin_so_nsubj', 'resist_so_nsubj', 'abound_s_nsubj', 'name_so_nsubj', 'split_so_nsubj', 'blast_so_nsubj', 'told_sso_nsubj', 'call_ss_nsubj', 'argu_s_nsubj', 'suggest_s_nsubj']
# Nouns:
# ['he', 'marx', 'she', 'and', 'engels', 'paul', 'sky', 'grant', 'chapter', 'shells', 'this', 'others', 'tide', 'economists', 'minister', 'dennis', 'althusser', 'cox', 'leapor', '‘']
#
#
#
# Class: 86
# Verbs:
# ['depend_s_nsubj', 'appli_s_nsubj', 'result_s_nsubj', 'lead_s_nsubj', 'provid_so_nsubj', 'involv_so_nsubj', 'repres_so_nsubj', 'requir_so_nsubj', 'affect_so_nsubj', 'make_so_nsubj', 'give_so_nsubj', 'happen_s_nsubj', 'occur_s_nsubj', 'give_soo_nsubj', 'allow_so_nsubj', 'caus_so_nsubj', 'come_s_nsubj', 'led_s_nsubj', 'mean_so_nsubj', 'follow_so_dobj']
# Nouns:
# ['this', 'it', 'change', 'changes', 'success', 'approach', 'fact', 'decision', 'case', 'use', 'system', 'act', 'DIGIT', 'process', 'much', 'failure', 'rules', 'move', 'development', 'law']
#
#
#
# Class: 87
# Verbs:
# ['play_so_nsubj', 'talk_s_nsubj', 'gain_so_nsubj', 'examin_so_nsubj', 'came_so_nsubj', 'reject_so_nsubj', 'collect_so_nsubj', 'gave_so_nsubj', 'call_oso_nsubj', 'admit_so_nsubj', 'finish_so_nsubj', 'handl_so_nsubj', 'hold_s_nsubj', 'lift_so_nsubj', 'compar_so_nsubj', 'drove_s_nsubj', 'investig_so_nsubj', 'arrang_so_nsubj', 'star_o_dobj', 'consid_so_nsubj']
# Nouns:
# ['he', 'we', 'officials', 'jones', 'saw', 'police', 'scientists', 'study', 'hayling', 'commission', 'authors', 'scotland', 'board', 'judge', 'patrol', 'judges', 'team', 'factors', 'england', 'club']
#
#
#
# Class: 88
# Verbs:
# ['repres_so_dobj', 'wa_ss_nsubj', 'cost_so_dobj', 'involv_so_dobj', 'earn_so_dobj', 'requir_so_dobj', 'made_soo_dobj', 'expect_so_dobj', 'demand_so_dobj', 'cost_soo_dobj', 'inspir_so_dobj', 'rais_so_dobj', 'save_o_dobj', 'bring_soo_dobj', 'earn_soo_dobj', 'owe_so_dobj', 'want_so_dobj', 'invest_so_dobj', 'express_so_dobj', "'ve_so_dobj"]
# Nouns:
# ['money', 'more', 'mind', 'times', 'growth', 'interest', 'million', 'spirit', 'confidence', 'feeling', 'commitment', 'smile', 'machines', 'respect', '$', 'investment', 'deal', 'machine', 'trade', 'enthusiasm']
#
#
#
# Class: 89
# Verbs:
# ['live_s_nsubj', 'work_s_nsubj', 'die_s_nsubj', 'use_so_nsubj', 'ha_so_nsubj', 'suffer_s_nsubj', 'come_s_nsubj', 'play_s_nsubj', 'know_so_nsubj', 'care_s_nsubj', 'play_so_nsubj', 'join_so_nsubj', 'came_s_nsubj', 'attend_so_nsubj', 'held_so_nsubj', 'made_so_nsubj', 'receiv_so_nsubj', 'pass_so_nsubj', 'run_so_nsubj', 'stay_s_nsubj']
# Nouns:
# ['who', 'he', 'she', 'they', 'i', 'that', 'people', 'which', 'one', 'it', 'man', 'you', 'many', 'most', 'family', 'DIGIT', 'children', 'father', 'we', 'men']
#
#
#
# Class: 90
# Verbs:
# ['gave_soo_iobj', 'give_soo_iobj', 'ask_so_dobj', 'told_so_dobj', 'give_oo_iobj', 'tell_so_dobj', 'help_so_dobj', 'put_so_dobj', 'tell_o_dobj', 'brought_so_dobj', 'remind_so_dobj', 'let_o_dobj', 'bring_so_dobj', 'join_so_dobj', 'offer_soo_iobj', 'see_so_dobj', 'let_so_dobj', 'leav_so_dobj', 'want_so_dobj', 'left_so_dobj']
# Nouns:
# ['them', 'me', 'him', 'us', 'her', 'you', 'it', 'people', 'yourself', 'one', 'children', 'everyone', 'world', 'himself', 'group', 'child', 'anyone', 'police', 'members', 'myself']
#
#
#
# Class: 91
# Verbs:
# ['show_so_dobj', 'reduc_so_dobj', 'vari_s_nsubj', 'show_o_dobj', 'increas_so_dobj', 'reflect_so_dobj', 'display_so_dobj', 'show_soo_dobj', 'increas_s_nsubj', 'demonstr_so_dobj', 'reduc_o_dobj', 'increas_o_dobj', 'climb_so_dobj', 'improv_so_dobj', 'indic_so_dobj', 'use_oo_dobj', 'exhibit_so_dobj', 'reveal_so_dobj', 'decreas_s_nsubj', 'affect_so_dobj']
# Nouns:
# ['signs', 'size', 'number', 'amount', 'quality', 'speed', 'level', 'interest', 'levels', 'rate', 'risk', 'rates', 'trees', 'extent', 'ability', 'sign', 'differences', 'know', 'cost', 'structure']
#
#
#
# Class: 92
# Verbs:
# ['use_so_dobj', 'use_o_dobj', 'use_oo_dobj', 'ha_sooo_dobj', 'describ_so_dobj', 'use_soo_dobj', 'develop_so_dobj', 'appli_so_dobj', 'add_so_dobj', 'featur_so_dobj', 'use_os_dobj', 'use_sooo_dobj', 'combin_so_dobj', 'cast_so_dobj', 'incorpor_so_dobj', 'appli_o_dobj', 'call_soo_dobj', 'employ_so_dobj', 'knit_o_dobj', 'requir_so_dobj']
# Nouns:
# ['them', 'number', 'technology', 'techniques', 'methods', 'method', 'technique', 'language', 'system', 'test', 'features', 'words', 'one', 'materials', 'approach', 'procedures', 'information', 'skills', 'rules', 'data']
#
#
#
# Class: 93
# Verbs:
# ['use_soo_dobj', 'develop_so_dobj', 'look_s_csubj', 'offer_soo_dobj', 'enjoy_so_dobj', 'featur_o_dobj', 'give_sooo_dobj', 'arrang_so_dobj', 'receiv_sso_nsubj', 'combin_soo_dobj', 'enjoy_o_dobj', 'end_so_dobj', 'ha_sooo_dobj', 'lie_so_dobj', 'offer_soooo_dobj', 'creat_o_dobj', 'carri_soo_dobj', 'cover_o_dobj', 'provid_os_csubj', "'s_sss_nsubj"]
# Nouns:
# ['look', 'looking', 'career', 'return', 'providing', 'looks', 'sitting', 'counselling', 'atmosphere', 'passion', 'tv', 'roses', 'pool', 'visiting', 'wonder', 'display', 'friendship', 'season', 'couples', 'french']
#
#
#
# Class: 94
# Verbs:
# ['stop_s_nsubj', 'ask_s_nsubj', 'rang_s_nsubj', 'place_so_nsubj', 'caught_so_nsubj', 'ad_s_nsubj', 'drop_s_nsubj', 'pull_s_nsubj', 'run_s_nsubj', 'rang_so_dobj', 'ran_so_nsubj', 'slip_s_nsubj', 'pull_so_nsubj', 'grab_so_nsubj', 'carri_so_nsubj', 'ran_s_nsubj', 'stop_so_dobj', 'touch_so_nsubj', 'drew_s_nsubj', 'drive_so_dobj']
# Nouns:
# ['car', 'train', 'cars', 'wind', 'bell', 'phone', 'he', 'then', 'stop', 'engine', 'telephone', 'trains', 'selling', 'dog', 'plane', 'van', 'man', 'one', 'ship', 'bells']
#
#
#
# Class: 95
# Verbs:
# ['said_so_nsubj', 'open_so_nsubj', 'sit_s_nsubj', 'enjoy_so_nsubj', 'write_s_nsubj', 'visit_so_nsubj', 'wrote_so_nsubj', 'stop_so_nsubj', 'lose_so_nsubj', 'write_so_nsubj', 'head_so_nsubj', 'jump_s_nsubj', 'give_sso_nsubj', 'drift_s_nsubj', 'divid_so_nsubj', 'retir_s_nsubj', 'fire_s_nsubj', 'captur_so_nsubj', 'get_sso_nsubj', 'attend_s_nsubj']
# Nouns:
# ['he', 'she', 'who', 'police', 'you', 'i', 'no', 'they', 'that', 'we', 'here', 'all', 'one', 'man', 'their', 'the', 'DIGIT', 'policemen', 'major', 'men']
#
#
#
# Class: 96
# Verbs:
# ['come_s_nsubj', 'appear_s_nsubj', 'meet_so_dobj', 'fit_so_dobj', 'satisfi_so_dobj', 'met_so_dobj', 'forget_so_dobj', 'remind_so_nsubj', 'meet_o_dobj', 'meet_soo_dobj', 'expand_s_nsubj', 'control_so_nsubj', 'break_so_nsubj', 'confront_so_dobj', 'undergo_so_nsubj', 'fulfil_so_dobj', 'damag_so_nsubj', 'fix_so_dobj', 'suppli_so_dobj', 'suit_so_dobj']
# Nouns:
# ['needs', 'requirements', 'most', 'it', 'bill', 'criteria', 'time', 'man', 'one', 'evidence', 'some', 'parties', 'demands', 'spots', 'name', 'requirement', 'arguments', 'horns', 'people', 'half']
#
#
#
# Class: 97
# Verbs:
# ['look_s_nsubj', 'seem_s_nsubj', 'came_s_nsubj', 'wa_s_nsubj', "'s_s_nsubj", 'work_s_nsubj', 'come_s_nsubj', 'make_so_nsubj', 'goe_s_nsubj', 'love_so_dobj', 'see_so_dobj', 'reach_so_nsubj', 'put_so_dobj', 'start_s_nsubj', 'leav_so_dobj', 'spot_so_dobj', 'provid_so_nsubj', 'run_s_nsubj', 'saw_so_dobj', 'turn_s_nsubj']
# Nouns:
# ['it', 'boy', 'one', 'man', 'talk', 'news', 'everything', 'face', 'music', 'film', 'animal', 'world', 'this', 'many', 'reason', 'time', 'body', 'company', 'group', 'idea']
#
#
#
# Class: 98
# Verbs:
# ['see_o_dobj', 'see_oo_dobj', 'walk_s_nsubj', 'call_o_dobj', 'see_so_dobj', 'consult_so_dobj', 'recommend_so_nsubj', 'examin_so_nsubj', 'see_os_dobj', 'list_so_nsubj', 'walk_ss_nsubj', 'give_so_nsubj', 'consult_o_dobj', 'quot_so_nsubj', 'conclud_s_nsubj', 'left_sso_nsubj', 'provid_so_nsubj', 'appoint_so_dobj', 'summaris_so_nsubj', 'made_ssso_nsubj']
# Nouns:
# ['page', 'chapter', 'table', 'figure', 'p.', 'section', 'c', 'fig.', 'p', 'doctor', 'walking', 'no.', 'committee', 'box', 'task', 'recipe', 'pages', 'DIGIT', 'appendix', 'chart']
#
#
#
# Class: 99
# Verbs:
# ['dot_s_csubj', 'share_sso_nsubj', 'give_so_csubj', 'began_ss_nsubj', 'took_so_csubj', 'mean_ss_nsubj', 'keep_sso_nsubj', 'emerg_ss_csubj', 'help_os_csubj', 'provid_so_csubj', 'caus_so_csubj', 'allow_so_csubj', 'wa_s_csubj', 'see_so_csubj', 'dot_ss_csubj', 'tumbl_so_dobj', 'describ_ssso_nsubj', 'vent_so_dobj', 'attribut_os_nsubj', 'track_o_dobj']
# Nouns:
# ['dot', 'objectives', 'helping', 'aims', 'social', 'collecting', 'raiders', 'perspectives', 'latest', 'emerges', 'anxieties', 'gel', 'arrows', 'emerged', 'stepping', 'pits', 'conduct', 'savage', 'affected', 'carriages']
#
#
#
# Class: 100
# Verbs:
# ['provid_so_nsubj', 'run_so_dobj', 'run_o_dobj', 'launch_so_dobj', 'includ_so_nsubj', 'includ_sooo_dobj', 'ha_so_dobj', 'oper_so_dobj', 'ran_so_dobj', 'includ_soo_dobj', 'run_s_nsubj', 'provid_sso_nsubj', 'support_so_dobj', 'plan_so_dobj', 'includ_so_dobj', 'join_so_dobj', 'work_s_nsubj', 'oper_s_nsubj', 'hous_so_dobj', 'use_so_nsubj']
# Nouns:
# ['system', 'service', 'systems', 'programme', 'software', 'version', 'scheme', 'centre', 'business', 'series', 'unit', 'group', 'products', 'courses', 'staff', 'campaign', 'applications', 'company', 'services', 'network']

# %%
 test =

# %%
'%.2E'%(2.64390243897e-34)
# Out:
# '2.64E-34'
